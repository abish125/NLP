# %%
#this is the main program: I will put the parts below here#first I pull the data from the csv#then I split it up by commas and get all the cells by row#then get the final diagnosis rows and the text columnimport csvfrom nltk import *hello = ""h = []with open('/home/andrew/Desktop/f.csv', 'rb') as csvfile:    spamreader = csv.reader(csvfile, delimiter=',')    for row in spamreader:        if row[2]=="Final Diagnosis":            #print row[3]            hello = row[3]            h=set(hello.split())            h = sorted(h)            fdist1 = FreqDist(h)            vocabulary1 = fdist1.keys()            print vocabulary1[:50]
# Out:
# ['(FDA).', '(below)', '16', '2', '20%', '3,', '30%.', ';', 'A.', 'B', 'B-cell', 'Bcl-2', 'Bcl-6', 'CD10', 'CD20+', 'CD21', 'CD3+', 'Clinical', 'Dr.', 'EXCISION,', 'FDA', 'Flow', 'Giemsa', 'Harris', 'INGUINAL:', 'Immunohistochemical', 'In', 'It', 'Ki67', 'LEFT', 'LYMPH', 'Massachusetts', 'NODE', 'Nancy', 'Note:', 'Overall,', 'Selected', 'T', 'The', 'There', 'This', 'U.S.', 'a', 'about', 'accuracy', 'adipose', 'administration', 'admixture', 'also', 'an']['(15.0', '(2,220', '(below)', 'A.', 'B', 'Concurrent', 'Few', 'Large', 'Note:', 'SPLEEN,', 'SPLENECTOMY:', 'Splenomegaly', 'T-cell', 'abnormal', 'and', 'are', 'cm).', 'congestion,', 'cytometry', 'expansion', 'fibrosis.', 'flow', 'gram)', 'hemorrhage', 'in', 'infarct', 'megakaryocytes', 'no', 'of', 'or', 'patchy', 'population.', 'pulp,', 'pulp.', 'recent', 'red', 'scattered', 'seen', 'shows', 'subcapsular', 'the', 'with']['(S11-71527).', '(S11-71527;', '(See', '(out', '0%', '1%', '1+', '10/27/11)', '11%', '12/29/11', '13%', '18%', '19%'
# ...

# %%
#here I am finding the captial letters that determine the final diagnosisimport nltk
